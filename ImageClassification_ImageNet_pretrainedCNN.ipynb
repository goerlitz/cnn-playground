# %% [markdown]
# # Image Classification with pre-trained CNN Models
#
# All models are included in [Keras](https://keras.io/applications/#documentation-for-individual-models) are were trained on ImageNet.
#
# Test with:
#   * VGG16
#   * ResNet50
#   * InceptionV3
#   * Xception
#   * InceptionResNetV2
#   * NasNetLarge
#   * NasNetMobile
#
# based on:
#
#   * [Jason Brownlee: How to Use The Pre-Trained VGG Model to Classify Objects in Photographs](https://machinelearningmastery.com/use-pre-trained-vgg-model-classify-objects-photographs/) (2017-11-08)
#   * [Keras deep learning models wirh pre-trained weights](https://keras.io/applications/)

# %% [markdown]
# ## Load Image

# %%
img1 = "https://c1.staticflickr.com/6/5259/5393739840_938b56b479_b.jpg"

# %%
from urllib.request import urlretrieve
urlretrieve (img1, "img1.jpg")
# Out:
# ('img1.jpg', <http.client.HTTPMessage at 0x7fed4f25ff60>)

# %%
from keras.preprocessing.image import load_img

# load an image from file
image = load_img("img1.jpg", target_size=(224, 224))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FED4F277A58>

# %%
from keras.preprocessing.image import img_to_array

# convert the image pixels to a numpy array
image = img_to_array(image)

# %%
# reshape data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

# %%
from keras.applications.vgg16 import preprocess_input

# prepare the image for the VGG model
image = preprocess_input(image)

# %% [markdown]
# # VGG16

# %%
from keras.applications.vgg16 import VGG16
model = VGG16()

# %%
#model.summary()

# %%
# predict the probability across all output classes
yhat = model.predict(image)

# %%
from keras.applications.vgg16 import decode_predictions

# convert the probabilities to class labels
label = decode_predictions(yhat)

# %%
label
# Out:
# [[('n07745940', 'strawberry', 0.9846711),
#   ('n07614500', 'ice_cream', 0.0033716366),
#   ('n07760859', 'custard_apple', 0.00126416),
#   ('n04476259', 'tray', 0.0012218364),
#   ('n07753113', 'fig', 0.0010088716)]]

# %%
# retrieve the most likely result, e.g. highest probability
label = label[0][0]
# print the classification
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# strawberry (98.47%)

# %% [markdown]
# # ResNet50

# %%
from keras.applications.resnet50 import ResNet50
model = ResNet50()

# %%
#model.summary()

# %%
yhat = model.predict(image)
label = decode_predictions(yhat)
label
# Out:
# [[('n07745940', 'strawberry', 0.9974051),
#   ('n07753592', 'banana', 0.0006487568),
#   ('n07760859', 'custard_apple', 0.0005292222),
#   ('n07836838', 'chocolate_sauce', 0.00021352575),
#   ('n07614500', 'ice_cream', 0.00019791834)]]
